# %% [markdown]
# **ID Last digit: 7**

# %% [markdown]
# **My own example 1 - Polinomio Grado 10**
#
# (x-3)(x-5)(x-1)(x-7)(x-6)(x-21)(x-58)(x-27)(x-31)(x-20) = 12845271600 - 26037528300 x + 18638528616 x^2 - 6627987129 x^3 + 1329424183 x^4 - 158717117 x^5 + 11500379 x^6 - 505067 x^7 + 13013 x^8 - 179 x^9 + x^10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **My own example 1 - Dividiendo por una raiz que esta dentro del polinomio**
#
# (12845271600 - 26037528300 x + 18638528616 x^2 - 6627987129 x^3 + 1329424183 x^4 - 158717117 x^5 + 11500379 x^6 - 505067 x^7 + 13013 x^8 - 179 x^9 + x^10) / (x-7)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **My own example 1 - Dividiendo por una raiz que esta fuera del polinomio**
#
# (12845271600 - 26037528300 x + 18638528616 x^2 - 6627987129 x^3 + 1329424183 x^4 - 158717117 x^5 + 11500379 x^6 - 505067 x^7 + 13013 x^8 - 179 x^9 + x^10) / (x-2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **My own example 2 - Polinomio en sympy**

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

polynomial = x**10 - 179*x**9 + 13013*x**8 - 505067*x**7 + 11500379*x**6 - 158717117*x**5 + 1329424183*x**4 - 6627987129*x**3 + 18638528616*x**2 - 26037528300*x + 12845271600

factors = [3, 5, 1, 7, 6, 21, 58, 27, 31, 20]

for i in factors:
    polynomial, r = div(polynomial, x-i)
    print(f"Dividiendo por: (x-{i}):")
    print(f"Cociente: {polynomial}")
    print(f"Residuo: {r}\n")
# Out:
# Dividiendo por: (x-3):
# Cociente: x**9 - 176*x**8 + 12485*x**7 - 467612*x**6 + 10097543*x**5 - 128424488*x**4 + 944150719*x**3 - 3795534972*x**2 + 7251923700*x - 4281757200
# Residuo: 0
#
# Dividiendo por: (x-5):
# Cociente: x**8 - 171*x**7 + 11630*x**6 - 409462*x**5 + 8050233*x**4 - 88173323*x**3 + 503284104*x**2 - 1279114452*x + 856351440
# Residuo: 0
#
# Dividiendo por: (x-1):
# Cociente: x**7 - 170*x**6 + 11460*x**5 - 398002*x**4 + 7652231*x**3 - 80521092*x**2 + 422763012*x - 856351440
# Residuo: 0
#
# Dividiendo por: (x-7):
# Cociente: x**6 - 163*x**5 + 10319*x**4 - 325769*x**3 + 5371848*x**2 - 42918156*x + 122335920
# Residuo: 0
#
# Dividiendo por: (x-6):
# Cociente: x**5 - 157*x**4 + 9377*x**3 - 269507*x**2 + 3754806*x - 20389320
# Residuo: 0
#
# Dividiendo por: (x-21):
# Cociente: x**4 - 136*x**3 + 6521*x**2 - 132566*x + 970920
# Residuo: 0
#
# Dividiendo por: (x-58):
# Cociente: x**3 - 78*x**2 + 1997*x - 16740
# Residuo: 0
#
# Dividiendo por: (x-27):
# Cociente: x**2 - 51*x + 620
# Residuo: 0
#
# Dividiendo por: (x-31):
# Cociente: x - 20
# Residuo: 0
#
# Dividiendo por: (x-20):
# Cociente: 1
# Residuo: 0

# %% [markdown]
# **My own example 2 - Polinomio en sympy diviendo por un factor que no esta en la ecuación**

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

polynomial = x**10 - 179*x**9 + 13013*x**8 - 505067*x**7 + 11500379*x**6 - 158717117*x**5 + 1329424183*x**4 - 6627987129*x**3 + 18638528616*x**2 - 26037528300*x + 12845271600

polynomial, r = div(polynomial,  x-2)

print(polynomial)
print(r)
# Out:
# x**9 - 177*x**8 + 12659*x**7 - 479749*x**6 + 10540881*x**5 - 137635355*x**4 + 1054153473*x**3 - 4519680183*x**2 + 9599168250*x - 6839191800
# -833112000

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*5 - 15\*x\*\*4  + 85\*x\*\*3 - 225\*x\*\*2 + 274\*x - 120)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram3.jpg" />

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**5 - 15*x**4  + 85*x**3 - 225*x**2 + 274*x - 120)
# Out:
# (x - 5)*(x - 4)*(x - 3)*(x - 2)*(x - 1)

# %% [markdown]
# **My own example 3**

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 179*x**9 + 13013*x**8 - 505067*x**7 + 11500379*x**6 - 158717117*x**5 + 1329424183*x**4 - 6627987129*x**3 + 18638528616*x**2 - 26037528300*x + 12845271600)
# Out:
# (x - 58)*(x - 31)*(x - 27)*(x - 21)*(x - 20)*(x - 7)*(x - 6)*(x - 5)*(x - 3)*(x - 1)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x\*\*5 - 15\*x\*\*4  + 85\*x\*\* 3 - 225\*x\*\* 2 + 274\*x - 120 = 0

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram4.jpg" />

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**5 - 15*x**4  + 85*x**3 - 225*x**2 + 274*x - 120, 0), x)
# Out:
# FiniteSet(1, 2, 3, 4, 5)

# %% [markdown]
# **My own example 4**

# %%
from sympy import Symbol, solveset, Eq
y = Symbol('x')
solveset(Eq(x**10 - 179*x**9 + 13013*x**8 - 505067*x**7 + 11500379*x**6 - 158717117*x**5 + 1329424183*x**4 - 6627987129*x**3 + 18638528616*x**2 - 26037528300*x + 12845271600,0),x)
# Out:
# {1, 3, 5, 6, 7, 20, 21, 27, 31, 58}

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram5.jpg" />

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2 - (sqrt(2)+E)*x + (sqrt(2)*pi) , 0), x)
# Out:
# FiniteSet(sqrt(2)/2 + E/2 - I*sqrt(-(sqrt(2) + E)**2 + 4*sqrt(2)*pi)/2, sqrt(2)/2 + E/2 + I*sqrt(-(sqrt(2) + E)**2 + 4*sqrt(2)*pi)/2)

# %% [markdown]
# **My own example 5**

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq( x**10 - x**9 + (sqrt(9)+pi)*x**8 - 13*x**7 + (sqrt(59)+pi)*x**6 - 14**x*5 + (sqrt(24)+pi)*x**4 - 3*x**3 + (sqrt(9)+pi)*x**2 - 60*x + (sqrt(22)+pi),0), x)
# Out:
# ConditionSet(x, Eq(-5*14**x + x**10 - x**9 + x**8*(3 + pi) - 13*x**7 + x**6*(pi + sqrt(59)) + x**4*(pi + 2*sqrt(6)) - 3*x**3 + x**2*(3 + pi) - 60*x + pi + sqrt(22), 0), Complexes)

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram6.jpg" />

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**5 - 2*x**4  - x**3 + 8*x**2 - 10*x - 4,domain='GF(3)')
# Out:
# (x + 1)*(x**4 - x**2 - 1)

# %% [markdown]
# **My  own example  6**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
y = Symbol('x')
factor(x**10 - 179*x**9 + 13013*x**8 - 505067*x**7 + 11500379*x**6 - 158717117*x**5 + 1329424183*x**4 - 6627987129*x**3 + 18638528616*x**2 - 26037528300*x + 12845271600, domain='GF(2)')
# Out:
# x**3*(x + 1)**7

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# **My  own example  6**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
y1, y2, z1, z2, x1, x2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = 59*x1 + I*x2
y = 24*y1 + I*y2
z = 60*z1 + I*z2

print(x*y)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
u=1/(2*pi + I)
print('u=',u)
u=N(u)
print('u=',u)
# Out:
# (24*x1 + I*x2)*(59*z1 + I*z2)
# 84960*x1*y1*z1 + 1440*I*x1*y1*z2 + 1416*I*x1*y2*z1 - 24*x1*y2*z2 + 3540*I*x2*y1*z1 - 60*x2*y1*z2 - 59*x2*y2*z1 - I*x2*y2*z2
# 84960*x1*y1*z1 + 1440*I*x1*y1*z2 + 1416*I*x1*y2*z1 - 24*x1*y2*z2 + 3540*I*x2*y1*z1 - 60*x2*y1*z2 - 59*x2*y2*z1 - I*x2*y2*z2
# 84960*x1*y1*z1 + 1440*I*x1*y1*z2 + 1416*I*x1*y2*z1 - 24*x1*y2*z2 + 3540*I*x2*y1*z1 - 60*x2*y1*z2 - 59*x2*y2*z1 - I*x2*y2*z2
# u= 1/(2*pi + I)
# u= 0.155223096134648 - 0.0247045230318576*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram8.jpg" />

# %% [markdown]
# **My own example 7**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **My own example 8**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram9.jpg" />

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**3, x)
# Out:
# -x**2*sin(x)**2*cos(x) - 2*x**2*cos(x)**3/3 + 14*x*sin(x)**3/9 + 4*x*sin(x)*cos(x)**2/3 + 14*sin(x)**2*cos(x)/9 + 40*cos(x)**3/27

# %% [markdown]
# **My own example 9**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**3 * cos(x)**3, x)
# Out:
# 2*x**3*sin(x)**3/3 + x**3*sin(x)*cos(x)**2 + 2*x**2*sin(x)**2*cos(x) + 7*x**2*cos(x)**3/3 - 40*x*sin(x)**3/9 - 14*x*sin(x)*cos(x)**2/3 - 40*sin(x)**2*cos(x)/9 - 122*cos(x)**3/27

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram10.jpg" />

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**3, (x,1,5))
# Out:
# 70*sin(5)**3/9 - 211*sin(5)**2*cos(5)/9 - 14*sin(1)**3/9 + 20*sin(5)*cos(5)**2/3 - 410*cos(5)**3/27 - 4*sin(1)*cos(1)**2/3 - 5*sin(1)**2*cos(1)/9 - 22*cos(1)**3/27

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**2 * sin(x)**3, (x,1,5)))
# Out:
# -15.4297821533056

# %% [markdown]
# **My own example 10**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**3 * cos(x)**3, (x,3,6))
# Out:
# 188*sin(6)*cos(6)**2 + 352*sin(6)**3/3 - 13*sin(3)*cos(3)**2 - 14*sin(3)**3/3 - 122*sin(3)**2*cos(3)/9 + 608*sin(6)**2*cos(6)/9 - 445*cos(3)**3/27 + 2146*cos(6)**3/27

# %%
from sympy import Symbol, integrate, cos, N
x = Symbol('x')
N(integrate(x**3 * cos(x)**3, (x,3,6)))
# Out:
# 38.8809318530595
